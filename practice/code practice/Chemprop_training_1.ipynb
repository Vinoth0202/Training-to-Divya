# %% [markdown]
# ### Reference:
# https://chatgpt.com/share/6835154f-ad70-800f-9c7d-9fa80894ad6a

# %%
# !git clone https://github.com/chemprop/chemprop.git
# %cd chemprop
# !pip create -n chemprop_env python=3.9 -y
# !pip activate chemprop_env
# !pip install -e .
# Out:
# Cloning into 'chemprop'...
# remote: Enumerating objects: 25546, done.
# remote: Counting objects: 100% (384/384), done.
# remote: Compressing objects: 100% (194/194), done.
# remote: Total 25546 (delta 291), reused 190 (delta 190), pack-reused 25162 (from 2)
# Receiving objects: 100% (25546/25546), 895.35 MiB | 28.60 MiB/s, done.
# Resolving deltas: 100% (18335/18335), done.
# /content/chemprop/chemprop/chemprop
# ERROR: unknown command "create"
# ERROR: unknown command "activate"
# Obtaining file:///content/chemprop/chemprop/chemprop
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: lightning>=2.0 in /usr/local/lib/python3.11/dist-packages (from chemprop==2.1.2) (2.5.1.post0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from chemprop==2.1.2) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from chemprop==2.1.2) (2.2.2)
# Requirement already satisfied: rdkit in /usr/local/lib/python3.11/dist-packages (from chemprop==2.1.2) (2025.3.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from chemprop==2.1.2) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from chemprop==2.1.2) (1.15.3)
# Requirement already satisfied: torch>=2.1 in /usr/local/lib/python3.11/dist-packages (from chemprop==2.1.2) (2.6.0+cu124)
# Requirement already satisfied: astartes[molecules] in /usr/local/lib/python3.11/dist-packages (from chemprop==2.1.2) (1.3.1)
# Requirement already satisfied: ConfigArgParse in /usr/local/lib/python3.11/dist-packages (from chemprop==2.1.2) (1.7.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from chemprop==2.1.2) (13.9.4)
# Requirement already satisfied: descriptastorus in /usr/local/lib/python3.11/dist-packages (from chemprop==2.1.2) (2.8.0)
# Requirement already satisfied: PyYAML<8.0,>=5.4 in /usr/local/lib/python3.11/dist-packages (from lightning>=2.0->chemprop==2.1.2) (6.0.2)
# Requirement already satisfied: fsspec<2026.0,>=2022.5.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0->chemprop==2.1.2) (2025.3.2)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from lightning>=2.0->chemprop==2.1.2) (0.14.3)
# Requirement already satisfied: packaging<25.0,>=20.0 in /usr/local/lib/python3.11/dist-packages (from lightning>=2.0->chemprop==2.1.2) (24.2)
# Requirement already satisfied: torchmetrics<3.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from lightning>=2.0->chemprop==2.1.2) (1.7.1)
# Requirement already satisfied: tqdm<6.0,>=4.57.0 in /usr/local/lib/python3.11/dist-packages (from lightning>=2.0->chemprop==2.1.2) (4.67.1)
# Requirement already satisfied: typing-extensions<6.0,>=4.4.0 in /usr/local/lib/python3.11/dist-packages (from lightning>=2.0->chemprop==2.1.2) (4.13.2)
# Requirement already satisfied: pytorch-lightning in /usr/local/lib/python3.11/dist-packages (from lightning>=2.0->chemprop==2.1.2) (2.5.1.post0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->chemprop==2.1.2) (3.18.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->chemprop==2.1.2) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->chemprop==2.1.2) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->chemprop==2.1.2) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->chemprop==2.1.2) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->chemprop==2.1.2) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->chemprop==2.1.2) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->chemprop==2.1.2) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->chemprop==2.1.2) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->chemprop==2.1.2) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->chemprop==2.1.2) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->chemprop==2.1.2) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->chemprop==2.1.2) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->chemprop==2.1.2) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->chemprop==2.1.2) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->chemprop==2.1.2) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->chemprop==2.1.2) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->chemprop==2.1.2) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.1->chemprop==2.1.2) (1.3.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.11/dist-packages (from astartes[molecules]->chemprop==2.1.2) (0.9.0)
# Requirement already satisfied: aimsim_core in /usr/local/lib/python3.11/dist-packages (from astartes[molecules]->chemprop==2.1.2) (2.2.2)
# Requirement already satisfied: pandas-flavor in /usr/local/lib/python3.11/dist-packages (from descriptastorus->chemprop==2.1.2) (0.7.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->chemprop==2.1.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->chemprop==2.1.2) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->chemprop==2.1.2) (2025.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from rdkit->chemprop==2.1.2) (11.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->chemprop==2.1.2) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->chemprop==2.1.2) (2.19.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->chemprop==2.1.2) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->chemprop==2.1.2) (3.6.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0->chemprop==2.1.2) (3.11.15)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from lightning-utilities<2.0,>=0.10.0->lightning>=2.0->chemprop==2.1.2) (75.2.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->chemprop==2.1.2) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->chemprop==2.1.2) (1.17.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from aimsim_core->astartes[molecules]->chemprop==2.1.2) (5.9.5)
# Requirement already satisfied: padelpy in /usr/local/lib/python3.11/dist-packages (from aimsim_core->astartes[molecules]->chemprop==2.1.2) (0.1.16)
# Requirement already satisfied: mhfp in /usr/local/lib/python3.11/dist-packages (from aimsim_core->astartes[molecules]->chemprop==2.1.2) (1.9.6)
# Requirement already satisfied: mordredcommunity in /usr/local/lib/python3.11/dist-packages (from aimsim_core->astartes[molecules]->chemprop==2.1.2) (2.0.6)
# Requirement already satisfied: multiprocess>=0.70 in /usr/local/lib/python3.11/dist-packages (from aimsim_core->astartes[molecules]->chemprop==2.1.2) (0.70.15)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.1->chemprop==2.1.2) (3.0.2)
# Requirement already satisfied: xarray in /usr/local/lib/python3.11/dist-packages (from pandas-flavor->descriptastorus->chemprop==2.1.2) (2025.3.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0->chemprop==2.1.2) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0->chemprop==2.1.2) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0->chemprop==2.1.2) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0->chemprop==2.1.2) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0->chemprop==2.1.2) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0->chemprop==2.1.2) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0->chemprop==2.1.2) (1.20.0)
# Requirement already satisfied: dill>=0.3.7 in /usr/local/lib/python3.11/dist-packages (from multiprocess>=0.70->aimsim_core->astartes[molecules]->chemprop==2.1.2) (0.3.7)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.11/dist-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0->chemprop==2.1.2) (3.10)
# Building wheels for collected packages: chemprop
#   Building editable for chemprop (pyproject.toml) ... done
#   Created wheel for chemprop: filename=chemprop-2.1.2-0.editable-py3-none-any.whl size=7658 sha256=d278099ece76951dfaf76001558204304fd4451b242e1707b5e5d55e1c6d62a2
#   Stored in directory: /tmp/pip-ephem-wheel-cache-vysvf3r6/wheels/6e/0d/48/be315c7a4681dfe2a6368453f2ac03df0448a7ea17cbce0cf2
# Successfully built chemprop
# Installing collected packages: chemprop
#   Attempting uninstall: chemprop
#     Found existing installation: chemprop 2.1.2
#     Uninstalling chemprop-2.1.2:
#       Successfully uninstalled chemprop-2.1.2
# Successfully installed chemprop-2.1.2

# %%
import pandas as pd
data = pd.read_csv("/content/SMILES_Big_Data_Set.csv")
print(data.columns)
data.head()
# Out:
# Index(['SMILES', 'pIC50', 'mol', 'num_atoms', 'logP'], dtype='object')
#                                               SMILES  pIC50  \
# 0         O=S(=O)(Nc1cccc(-c2cnc3ccccc3n2)c1)c1cccs1   4.26
# 1  O=c1cc(-c2nc(-c3ccc(-c4cn(CCP(=O)(O)O)nn4)cc3)...   4.34
# 2             NC(=O)c1ccc2c(c1)nc(C1CCC(O)CC1)n2CCCO   4.53
# 3                NCCCn1c(C2CCNCC2)nc2cc(C(N)=O)ccc21   4.56
# 4                  CNC(=S)Nc1cccc(-c2cnc3ccccc3n2)c1   4.59
#
#                                                 mol  num_atoms    logP
# 0  <rdkit.Chem.rdchem.Mol object at 0x7f59df45bc30>         25  4.1591
# 1  <rdkit.Chem.rdchem.Mol object at 0x7f59a320c9e0>         36  3.6743
# 2  <rdkit.Chem.rdchem.Mol object at 0x7f59a320cac0>         23  1.5361
# 3  <rdkit.Chem.rdchem.Mol object at 0x7f59a320cba0>         22  0.9510
# 4  <rdkit.Chem.rdchem.Mol object at 0x7f59a320c7b0>         21  3.2130

# %%
data = data.rename(columns={
    'SMILES': 'smiles',  # replace with actual column name
    'logP': 'target'   # replace with actual column name
})

# %%
data
# Out:
#                                                   smiles  pIC50  \
# 0             O=S(=O)(Nc1cccc(-c2cnc3ccccc3n2)c1)c1cccs1   4.26
# 1      O=c1cc(-c2nc(-c3ccc(-c4cn(CCP(=O)(O)O)nn4)cc3)...   4.34
# 2                 NC(=O)c1ccc2c(c1)nc(C1CCC(O)CC1)n2CCCO   4.53
# 3                    NCCCn1c(C2CCNCC2)nc2cc(C(N)=O)ccc21   4.56
# 4                      CNC(=S)Nc1cccc(-c2cnc3ccccc3n2)c1   4.59
# ...                                                  ...    ...
# 16082               S=C(NN=C(c1ccccn1)c1ccccn1)Nc1ccccc1   0.00
# 16083                            S=C=NCCCCCCCCCCc1ccccc1   0.00
# 16084                              S=C=NCCCCCCCCc1ccccc1   0.00
# 16085              S=c1[nH]nc(Cn2ccc3ccccc32)n1-c1ccccc1   0.00
# 16086                   N=[N+]=NC=Cc1ccc([N+](=O)[O-])o1   0.02
#
#                                                     mol  num_atoms   target
# 0      <rdkit.Chem.rdchem.Mol object at 0x7f59df45bc30>         25  4.15910
# 1      <rdkit.Chem.rdchem.Mol object at 0x7f59a320c9e0>         36  3.67430
# 2      <rdkit.Chem.rdchem.Mol object at 0x7f59a320cac0>         23  1.53610
# 3      <rdkit.Chem.rdchem.Mol object at 0x7f59a320cba0>         22  0.95100
# 4      <rdkit.Chem.rdchem.Mol object at 0x7f59a320c7b0>         21  3.21300
# ...                                                 ...        ...      ...
# 16082  <rdkit.Chem.rdchem.Mol object at 0x7f59a314ed50>         24  3.21560
# 16083  <rdkit.Chem.rdchem.Mol object at 0x7f59a314edc0>         19  5.45270
# 16084  <rdkit.Chem.rdchem.Mol object at 0x7f59a314ee30>         17  4.67250
# 16085  <rdkit.Chem.rdchem.Mol object at 0x7f59a314eea0>         22  3.93289
# 16086  <rdkit.Chem.rdchem.Mol object at 0x7f59a314ef10>         13  1.70887
#
# [16087 rows x 5 columns]

# %%
data[['smiles', 'target']].to_csv('formatted_data.csv', index=False)

# %%
# !chemprop train \
    --data-path formatted_data.csv \
    --save-dir model_output \
    --epochs 5 \
    --metric rmse

#  --dataset-type regression \
# Out:
# 2025-05-27T07:49:37 - INFO:chemprop.cli.main - Running in mode 'train' with args: {'smiles_columns': None, 'reaction_columns': None, 'no_header_row': False, 'num_workers': 0, 'batch_size': 64, 'accelerator': 'auto', 'devices': 'auto', 'rxn_mode': 'REAC_DIFF', 'multi_hot_atom_featurizer_mode': 'V2', 'keep_h': False, 'add_h': False, 'ignore_stereo': False, 'molecule_featurizers': None, 'descriptors_path': None, 'no_descriptor_scaling': False, 'no_atom_feature_scaling': False, 'no_atom_descriptor_scaling': False, 'no_bond_feature_scaling': False, 'atom_features_path': None, 'atom_descriptors_path': None, 'bond_features_path': None, 'config_path': None, 'data_path': PosixPath('formatted_data.csv'), 'output_dir': PosixPath('model_output'), 'remove_checkpoints': False, 'checkpoint': None, 'freeze_encoder': False, 'model_frzn': None, 'frzn_ffn_layers': 0, 'from_foundation': None, 'ensemble_size': 1, 'message_hidden_dim': 300, 'message_bias': False, 'depth': 3, 'undirected': False, 'dropout': 0.0, 'mpn_shared': False, 'activation': 'RELU', 'aggregation': 'norm', 'aggregation_norm': 100, 'atom_messages': False, 'ffn_hidden_dim': 300, 'ffn_num_layers': 1, 'batch_norm': False, 'multiclass_num_classes': 3, 'weight_column': None, 'target_columns': None, 'ignore_columns': None, 'no_cache': False, 'splits_column': None, 'task_type': 'regression', 'loss_function': None, 'v_kl': 0.0, 'eps': 1e-08, 'alpha': 0.1, 'metrics': ['rmse'], 'tracking_metric': 'val_loss', 'show_individual_scores': False, 'task_weights': None, 'warmup_epochs': 2, 'init_lr': 0.0001, 'max_lr': 0.001, 'final_lr': 0.0001, 'epochs': 5, 'patience': None, 'grad_clip': None, 'class_balance': False, 'split': 'RANDOM', 'split_sizes': [0.8, 0.1, 0.1], 'split_key_molecule': 0, 'num_replicates': 1, 'num_folds': None, 'save_smiles_splits': False, 'splits_file': None, 'data_seed': 0, 'pytorch_seed': None}
# Wrote config file to model_output/config.toml
# 2025-05-27T07:49:37 - INFO:chemprop.cli.train - Pulling data from file: formatted_data.csv
# 2025-05-27T07:49:41 - WARNING:chemprop.data.splitting - The return type of make_split_indices has changed in v2.1 - see help(make_split_indices)
# 2025-05-27T07:49:41 - INFO:chemprop.cli.train - train/val/test split_0 sizes: [12869, 1608, 1610]
# 2025-05-27T07:49:41 - INFO:chemprop.cli.train -
#       Summary of Training Data
# ┏━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┓
# ┃       Statistic ┃ Value (target) ┃
# ┡━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━┩
# │     Num. smiles │          12869 │
# │    Num. targets │          12869 │
# │        Num. NaN │              0 │
# │            Mean │           2.26 │
# │       Std. dev. │           1.61 │
# │          Median │           2.16 │
# │ % within 1 s.d. │            71% │
# │ % within 2 s.d. │            95% │
# └─────────────────┴────────────────┘
#
# 2025-05-27T07:49:41 - INFO:chemprop.cli.train -
#      Summary of Validation Data
# ┏━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┓
# ┃       Statistic ┃ Value (target) ┃
# ┡━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━┩
# │     Num. smiles │           1608 │
# │    Num. targets │           1608 │
# │        Num. NaN │              0 │
# │            Mean │           2.29 │
# │       Std. dev. │            1.6 │
# │          Median │            2.2 │
# │ % within 1 s.d. │            70% │
# │ % within 2 s.d. │            95% │
# └─────────────────┴────────────────┘
#
# 2025-05-27T07:49:41 - INFO:chemprop.cli.train -
#         Summary of Test Data
# ┏━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┓
# ┃       Statistic ┃ Value (target) ┃
# ┡━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━┩
# │     Num. smiles │           1610 │
# │    Num. targets │           1610 │
# │        Num. NaN │              0 │
# │            Mean │            2.2 │
# │       Std. dev. │           1.59 │
# │          Median │           2.12 │
# │ % within 1 s.d. │            71% │
# │ % within 2 s.d. │            95% │
# └─────────────────┴────────────────┘
#
# 2025-05-27T07:49:41 - INFO:chemprop.cli.train - Train data: mean = [2.25932304] | std = [1.61293454]
# 2025-05-27T07:49:48 - INFO:chemprop.cli.train - No loss function was specified! Using class default: <class 'chemprop.nn.metrics.MSE'>
# 2025-05-27T07:49:48 - INFO:chemprop.cli.train - MPNN(
#   (message_passing): BondMessagePassing(
#     (W_i): Linear(in_features=86, out_features=300, bias=False)
#     (W_h): Linear(in_features=300, out_features=300, bias=False)
#     (W_o): Linear(in_features=372, out_features=300, bias=True)
#     (dropout): Dropout(p=0.0, inplace=False)
#     (tau): ReLU()
#     (V_d_transform): Identity()
#     (graph_transform): GraphTransform(
#       (V_transform): Identity()
#       (E_transform): Identity()
#     )
#   )
#   (agg): NormAggregation()
#   (bn): Identity()
#   (predictor): RegressionFFN(
#     (ffn): MLP(
#       (0): Sequential(
#         (0): Linear(in_features=300, out_features=300, bias=True)
#       )
#       (1): Sequential(
#         (0): ReLU()
#         (1): Dropout(p=0.0, inplace=False)
#         (2): Linear(in_features=300, out_features=1, bias=True)
#       )
#     )
#     (criterion): MSE(task_weights=[[1.0]])
#     (output_transform): UnscaleTransform()
#   )
#   (X_d_transform): Identity()
#   (metrics): ModuleList(
#     (0): RMSE(task_weights=[[1.0]])
#     (1): MSE(task_weights=[[1.0]])
#   )
# )
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# 2025-05-27 07:49:49.203370: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748332189.236823    8036 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748332189.246850    8036 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-27 07:49:49.281129: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/callbacks/model_checkpoint.py:654: Checkpoint directory /content/chemprop/chemprop/chemprop/chemprop/model_output/model_0/checkpoints exists and is not empty.
# Loading `train_dataloader` to estimate number of stepping batches.
#
#   | Name            | Type               | Params | Mode
# ---------------------------------------------------------------
# 0 | message_passing | BondMessagePassing | 227 K  | train
# 1 | agg             | NormAggregation    | 0      | train
# 2 | bn              | Identity           | 0      | train
# 3 | predictor       | RegressionFFN      | 90.6 K | train
# 4 | X_d_transform   | Identity           | 0      | train
# 5 | metrics         | ModuleList         | 0      | train
# ---------------------------------------------------------------
# 318 K     Trainable params
# 0         Non-trainable params
# 318 K     Total params
# 1.273     Total estimated model params size (MB)
# 26        Modules in train mode
# 0         Modules in eval mode
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/core/saving.py:363: Skipping 'metrics' parameter because it is not possible to safely dump to YAML.
# Epoch 0: 100% 202/202 [00:40<00:00,  5.04it/s, v_num=1, train_loss_step=0.102]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/26 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/26 [00:00<?, ?it/s]
# Validation DataLoader 0:   4% 1/26 [00:00<00:03,  7.33it/s]
# Validation DataLoader 0:   8% 2/26 [00:00<00:03,  6.80it/s]
# Validation DataLoader 0:  12% 3/26 [00:00<00:03,  6.54it/s]
# Validation DataLoader 0:  15% 4/26 [00:00<00:03,  6.73it/s]
# Validation DataLoader 0:  19% 5/26 [00:00<00:03,  6.75it/s]
# Validation DataLoader 0:  23% 6/26 [00:00<00:02,  6.89it/s]
# Validation DataLoader 0:  27% 7/26 [00:01<00:02,  6.91it/s]
# Validation DataLoader 0:  31% 8/26 [00:01<00:02,  6.86it/s]
# Validation DataLoader 0:  35% 9/26 [00:01<00:02,  6.75it/s]
# Validation DataLoader 0:  38% 10/26 [00:01<00:02,  6.75it/s]
# Validation DataLoader 0:  42% 11/26 [00:01<00:02,  6.76it/s]
# Validation DataLoader 0:  46% 12/26 [00:01<00:02,  6.77it/s]
# Validation DataLoader 0:  50% 13/26 [00:01<00:01,  6.79it/s]
# Validation DataLoader 0:  54% 14/26 [00:02<00:01,  6.77it/s]
# Validation DataLoader 0:  58% 15/26 [00:02<00:01,  6.75it/s]
# Validation DataLoader 0:  62% 16/26 [00:02<00:01,  6.69it/s]
# Validation DataLoader 0:  65% 17/26 [00:02<00:01,  6.71it/s]
# Validation DataLoader 0:  69% 18/26 [00:02<00:01,  6.70it/s]
# Validation DataLoader 0:  73% 19/26 [00:02<00:01,  6.69it/s]
# Validation DataLoader 0:  77% 20/26 [00:02<00:00,  6.72it/s]
# Validation DataLoader 0:  81% 21/26 [00:03<00:00,  6.73it/s]
# Validation DataLoader 0:  85% 22/26 [00:03<00:00,  6.72it/s]
# Validation DataLoader 0:  88% 23/26 [00:03<00:00,  6.65it/s]
# Validation DataLoader 0:  92% 24/26 [00:03<00:00,  6.66it/s]
# Validation DataLoader 0:  96% 25/26 [00:03<00:00,  6.65it/s]
# Validation DataLoader 0: 100% 26/26 [00:03<00:00,  6.87it/s]
# Epoch 1: 100% 202/202 [00:40<00:00,  4.97it/s, v_num=1, train_loss_step=0.0355, val_loss=0.261, train_loss_epoch=0.627]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/26 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/26 [00:00<?, ?it/s]
# Validation DataLoader 0:   4% 1/26 [00:00<00:03,  7.55it/s]
# Validation DataLoader 0:   8% 2/26 [00:00<00:03,  7.07it/s]
# Validation DataLoader 0:  12% 3/26 [00:00<00:03,  6.74it/s]
# Validation DataLoader 0:  15% 4/26 [00:00<00:03,  6.85it/s]
# Validation DataLoader 0:  19% 5/26 [00:00<00:03,  6.78it/s]
# Validation DataLoader 0:  23% 6/26 [00:00<00:02,  6.87it/s]
# Validation DataLoader 0:  27% 7/26 [00:01<00:02,  6.81it/s]
# Validation DataLoader 0:  31% 8/26 [00:01<00:02,  6.81it/s]
# Validation DataLoader 0:  35% 9/26 [00:01<00:02,  6.78it/s]
# Validation DataLoader 0:  38% 10/26 [00:01<00:02,  6.79it/s]
# Validation DataLoader 0:  42% 11/26 [00:01<00:02,  6.78it/s]
# Validation DataLoader 0:  46% 12/26 [00:01<00:02,  6.80it/s]
# Validation DataLoader 0:  50% 13/26 [00:01<00:01,  6.81it/s]
# Validation DataLoader 0:  54% 14/26 [00:02<00:01,  6.77it/s]
# Validation DataLoader 0:  58% 15/26 [00:02<00:01,  6.73it/s]
# Validation DataLoader 0:  62% 16/26 [00:02<00:01,  6.71it/s]
# Validation DataLoader 0:  65% 17/26 [00:02<00:01,  6.55it/s]
# Validation DataLoader 0:  69% 18/26 [00:02<00:01,  6.33it/s]
# Validation DataLoader 0:  73% 19/26 [00:03<00:01,  6.11it/s]
# Validation DataLoader 0:  77% 20/26 [00:03<00:00,  6.00it/s]
# Validation DataLoader 0:  81% 21/26 [00:03<00:00,  5.87it/s]
# Validation DataLoader 0:  85% 22/26 [00:03<00:00,  5.75it/s]
# Validation DataLoader 0:  88% 23/26 [00:04<00:00,  5.62it/s]
# Validation DataLoader 0:  92% 24/26 [00:04<00:00,  5.52it/s]
# Validation DataLoader 0:  96% 25/26 [00:04<00:00,  5.44it/s]
# Validation DataLoader 0: 100% 26/26 [00:04<00:00,  5.61it/s]
# Epoch 2: 100% 202/202 [00:43<00:00,  4.65it/s, v_num=1, train_loss_step=0.0355, val_loss=0.0858, train_loss_epoch=0.132]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/26 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/26 [00:00<?, ?it/s]
# Validation DataLoader 0:   4% 1/26 [00:00<00:06,  3.89it/s]
# Validation DataLoader 0:   8% 2/26 [00:00<00:05,  4.01it/s]
# Validation DataLoader 0:  12% 3/26 [00:00<00:05,  4.35it/s]
# Validation DataLoader 0:  15% 4/26 [00:00<00:04,  4.80it/s]
# Validation DataLoader 0:  19% 5/26 [00:00<00:04,  5.08it/s]
# Validation DataLoader 0:  23% 6/26 [00:01<00:03,  5.37it/s]
# Validation DataLoader 0:  27% 7/26 [00:01<00:03,  5.49it/s]
# Validation DataLoader 0:  31% 8/26 [00:01<00:03,  5.62it/s]
# Validation DataLoader 0:  35% 9/26 [00:01<00:03,  5.62it/s]
# Validation DataLoader 0:  38% 10/26 [00:01<00:02,  5.70it/s]
# Validation DataLoader 0:  42% 11/26 [00:01<00:02,  5.76it/s]
# Validation DataLoader 0:  46% 12/26 [00:02<00:02,  5.84it/s]
# Validation DataLoader 0:  50% 13/26 [00:02<00:02,  5.89it/s]
# Validation DataLoader 0:  54% 14/26 [00:02<00:02,  5.93it/s]
# Validation DataLoader 0:  58% 15/26 [00:02<00:01,  5.94it/s]
# Validation DataLoader 0:  62% 16/26 [00:02<00:01,  5.95it/s]
# Validation DataLoader 0:  65% 17/26 [00:02<00:01,  6.00it/s]
# Validation DataLoader 0:  69% 18/26 [00:02<00:01,  6.03it/s]
# Validation DataLoader 0:  73% 19/26 [00:03<00:01,  6.05it/s]
# Validation DataLoader 0:  77% 20/26 [00:03<00:00,  6.10it/s]
# Validation DataLoader 0:  81% 21/26 [00:03<00:00,  6.10it/s]
# Validation DataLoader 0:  85% 22/26 [00:03<00:00,  6.11it/s]
# Validation DataLoader 0:  88% 23/26 [00:03<00:00,  6.07it/s]
# Validation DataLoader 0:  92% 24/26 [00:03<00:00,  6.10it/s]
# Validation DataLoader 0:  96% 25/26 [00:04<00:00,  6.12it/s]
# Validation DataLoader 0: 100% 26/26 [00:04<00:00,  6.32it/s]
# Epoch 3: 100% 202/202 [00:40<00:00,  5.04it/s, v_num=1, train_loss_step=0.0531, val_loss=0.0307, train_loss_epoch=0.0474]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/26 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/26 [00:00<?, ?it/s]
# Validation DataLoader 0:   4% 1/26 [00:00<00:03,  7.35it/s]
# Validation DataLoader 0:   8% 2/26 [00:00<00:03,  7.21it/s]
# Validation DataLoader 0:  12% 3/26 [00:00<00:03,  6.71it/s]
# Validation DataLoader 0:  15% 4/26 [00:00<00:03,  6.73it/s]
# Validation DataLoader 0:  19% 5/26 [00:00<00:03,  6.79it/s]
# Validation DataLoader 0:  23% 6/26 [00:00<00:02,  6.92it/s]
# Validation DataLoader 0:  27% 7/26 [00:01<00:02,  6.93it/s]
# Validation DataLoader 0:  31% 8/26 [00:01<00:02,  6.92it/s]
# Validation DataLoader 0:  35% 9/26 [00:01<00:02,  6.86it/s]
# Validation DataLoader 0:  38% 10/26 [00:01<00:02,  6.85it/s]
# Validation DataLoader 0:  42% 11/26 [00:01<00:02,  6.76it/s]
# Validation DataLoader 0:  46% 12/26 [00:01<00:02,  6.78it/s]
# Validation DataLoader 0:  50% 13/26 [00:01<00:01,  6.80it/s]
# Validation DataLoader 0:  54% 14/26 [00:02<00:01,  6.79it/s]
# Validation DataLoader 0:  58% 15/26 [00:02<00:01,  6.77it/s]
# Validation DataLoader 0:  62% 16/26 [00:02<00:01,  6.75it/s]
# Validation DataLoader 0:  65% 17/26 [00:02<00:01,  6.65it/s]
# Validation DataLoader 0:  69% 18/26 [00:02<00:01,  6.44it/s]
# Validation DataLoader 0:  73% 19/26 [00:03<00:01,  6.22it/s]
# Validation DataLoader 0:  77% 20/26 [00:03<00:00,  6.09it/s]
# Validation DataLoader 0:  81% 21/26 [00:03<00:00,  5.92it/s]
# Validation DataLoader 0:  85% 22/26 [00:03<00:00,  5.80it/s]
# Validation DataLoader 0:  88% 23/26 [00:04<00:00,  5.66it/s]
# Validation DataLoader 0:  92% 24/26 [00:04<00:00,  5.58it/s]
# Validation DataLoader 0:  96% 25/26 [00:04<00:00,  5.49it/s]
# Validation DataLoader 0: 100% 26/26 [00:04<00:00,  5.67it/s]
# Epoch 4: 100% 202/202 [00:40<00:00,  5.03it/s, v_num=1, train_loss_step=0.0467, val_loss=0.0201, train_loss_epoch=0.0243]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/26 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/26 [00:00<?, ?it/s]
# Validation DataLoader 0:   4% 1/26 [00:00<00:03,  7.51it/s]
# Validation DataLoader 0:   8% 2/26 [00:00<00:03,  7.36it/s]
# Validation DataLoader 0:  12% 3/26 [00:00<00:03,  6.93it/s]
# Validation DataLoader 0:  15% 4/26 [00:00<00:03,  7.01it/s]
# Validation DataLoader 0:  19% 5/26 [00:00<00:02,  7.02it/s]
# Validation DataLoader 0:  23% 6/26 [00:00<00:02,  6.99it/s]
# Validation DataLoader 0:  27% 7/26 [00:01<00:02,  6.98it/s]
# Validation DataLoader 0:  31% 8/26 [00:01<00:02,  6.91it/s]
# Validation DataLoader 0:  35% 9/26 [00:01<00:02,  6.90it/s]
# Validation DataLoader 0:  38% 10/26 [00:01<00:02,  6.88it/s]
# Validation DataLoader 0:  42% 11/26 [00:01<00:02,  6.88it/s]
# Validation DataLoader 0:  46% 12/26 [00:01<00:02,  6.90it/s]
# Validation DataLoader 0:  50% 13/26 [00:01<00:01,  6.85it/s]
# Validation DataLoader 0:  54% 14/26 [00:02<00:01,  6.83it/s]
# Validation DataLoader 0:  58% 15/26 [00:02<00:01,  6.80it/s]
# Validation DataLoader 0:  62% 16/26 [00:02<00:01,  6.80it/s]
# Validation DataLoader 0:  65% 17/26 [00:02<00:01,  6.82it/s]
# Validation DataLoader 0:  69% 18/26 [00:02<00:01,  6.82it/s]
# Validation DataLoader 0:  73% 19/26 [00:02<00:01,  6.80it/s]
# Validation DataLoader 0:  77% 20/26 [00:02<00:00,  6.79it/s]
# Validation DataLoader 0:  81% 21/26 [00:03<00:00,  6.79it/s]
# Validation DataLoader 0:  85% 22/26 [00:03<00:00,  6.79it/s]
# Validation DataLoader 0:  88% 23/26 [00:03<00:00,  6.75it/s]
# Validation DataLoader 0:  92% 24/26 [00:03<00:00,  6.76it/s]
# Validation DataLoader 0:  96% 25/26 [00:03<00:00,  6.75it/s]
# Validation DataLoader 0: 100% 26/26 [00:03<00:00,  6.98it/s]
# Epoch 4: 100% 202/202 [00:43<00:00,  4.60it/s, v_num=1, train_loss_step=0.0467, val_loss=0.018, train_loss_epoch=0.0184]`Trainer.fit` stopped: `max_epochs=5` reached.
# Epoch 4: 100% 202/202 [00:43<00:00,  4.59it/s, v_num=1, train_loss_step=0.0467, val_loss=0.018, train_loss_epoch=0.0184]
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/connectors/checkpoint_connector.py:149: `.predict(ckpt_path=None)` was called without a model. The best model of the previous `fit` call will be used. You can pass `.predict(ckpt_path='best')` to use the best model or `.predict(ckpt_path='last')` to use the last model. If you pass a value, this warning will be silenced.
# Restoring states from the checkpoint path at /content/chemprop/chemprop/chemprop/chemprop/model_output/model_0/checkpoints/best-epoch=4-val_loss=0.02-v1.ckpt
# Loaded model weights from the checkpoint at /content/chemprop/chemprop/chemprop/chemprop/model_output/model_0/checkpoints/best-epoch=4-val_loss=0.02-v1.ckpt
# Predicting DataLoader 0: 100% 26/26 [00:02<00:00, 10.20it/s]
# 2025-05-27T07:53:42 - INFO:chemprop.cli.train - Test Set results:
# 2025-05-27T07:53:42 - INFO:chemprop.cli.train - test/rmse: 0.219491109251976
# 2025-05-27T07:53:42 - INFO:chemprop.cli.train - Best model saved to 'model_output/model_0/best.pt'
